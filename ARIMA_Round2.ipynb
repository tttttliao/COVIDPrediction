# %%
import os
import itertools

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %% [markdown]
# We first read in our train and test data. We assume that all the data are storedd as csv files in a separate `data` directory.

# %%
DIR_TRAIN_BY_STATE = "./data/train_by_state/"

train_data = pd.read_csv('./data/train_round2.csv', engine='python').filter(items=['ID', 'Province_State', 'Date', 'Confirmed', 'Deaths'])
test_data = pd.read_csv('./data/test_round2.csv', engine='python')
train_data.tail()
# Out:
#           ID Province_State        Date  Confirmed  Deaths
# 11245  11245       Virginia  11-22-2020     217796    3938
# 11246  11246     Washington  11-22-2020     141260    2619
# 11247  11247  West Virginia  11-22-2020      40478     662
# 11248  11248      Wisconsin  11-22-2020     376238    3150
# 11249  11249        Wyoming  11-22-2020      28169     176

# %% [markdown]
# Since we will potentially have a different model for every state, for convenience, we separate the train data into respective states to accelerate the learning steps.

# %%
# Get list of state names
states_names = np.unique(np.array([train_data['Province_State']]))
assert(len(states_names) == 50)
print(states_names)

def split_train_data_by_state(train_data):
    for state in states_names:
        state_data = train_data[train_data['Province_State'] == state]
        csv_name = DIR_TRAIN_BY_STATE + state + ".csv"
        state_data.to_csv(csv_name)
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois'
#  'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine' 'Maryland'
#  'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana'
#  'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'Rhode Island' 'South Carolina' 'South Dakota' 'Tennessee' 'Texas' 'Utah'
#  'Vermont' 'Virginia' 'Washington' 'West Virginia' 'Wisconsin' 'Wyoming']

# %% [markdown]
# But we only want to do this if we haven't done it already.

# %%
if not os.path.exists(DIR_TRAIN_BY_STATE):
    os.mkdir(DIR_TRAIN_BY_STATE)
    
if not len(os.listdir(DIR_TRAIN_BY_STATE)):
    split_train_data_by_state(train_data)

# %% [markdown]
# To get the best hyperparameters, we generate candidates to do a grid search for the one with best performance.

# %%
p = range(1, 5)
d = [1]
q = range(1, 8)
pdq_candidates = list(itertools.product(p, d, q))
seasonal_pdq_candidates = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print(pdq_candidates)
print(seasonal_pdq_candidates)
# Out:
# [(1, 1, 1), (1, 1, 2), (1, 1, 3), (1, 1, 4), (1, 1, 5), (1, 1, 6), (1, 1, 7), (2, 1, 1), (2, 1, 2), (2, 1, 3), (2, 1, 4), (2, 1, 5), (2, 1, 6), (2, 1, 7), (3, 1, 1), (3, 1, 2), (3, 1, 3), (3, 1, 4), (3, 1, 5), (3, 1, 6), (3, 1, 7), (4, 1, 1), (4, 1, 2), (4, 1, 3), (4, 1, 4), (4, 1, 5), (4, 1, 6), (4, 1, 7)]
# [(1, 1, 1, 12), (1, 1, 2, 12), (1, 1, 3, 12), (1, 1, 4, 12), (1, 1, 5, 12), (1, 1, 6, 12), (1, 1, 7, 12), (2, 1, 1, 12), (2, 1, 2, 12), (2, 1, 3, 12), (2, 1, 4, 12), (2, 1, 5, 12), (2, 1, 6, 12), (2, 1, 7, 12), (3, 1, 1, 12), (3, 1, 2, 12), (3, 1, 3, 12), (3, 1, 4, 12), (3, 1, 5, 12), (3, 1, 6, 12), (3, 1, 7, 12), (4, 1, 1, 12), (4, 1, 2, 12), (4, 1, 3, 12), (4, 1, 4, 12), (4, 1, 5, 12), (4, 1, 6, 12), (4, 1, 7, 12)]

# %%
def mape(pred, gt):
    ape = np.abs(pred - gt) / np.abs(gt)
    return np.mean(ape) * 100

# %%
def train_valid_split():
    valid_data = train_data[(train_data['Date'] >= "11-01-2020") & (train_data['Date'] <= "11-22-2020")]
    train_set = train_data[(train_data['Date'] < "11-01-2020")]
    valid_confirmed_dict = {}    
    valid_death_dict = {}
    train_confirmed_dict = {}    
    train_death_dict = {}

    for state in states_names:
        state_valid = valid_data[valid_data["Province_State"] == state]
        state_train = train_set[train_set["Province_State"] == state]

        state_valid_c = np.array(state_valid["Confirmed"].tolist())
        state_valid_d = np.array(state_valid["Deaths"].tolist())
        valid_confirmed_dict[state] = state_valid_c
        valid_death_dict[state] = state_valid_d
        
        state_train_c = np.array(state_train["Confirmed"].tolist())
        state_train_d = np.array(state_train["Deaths"].tolist())
        train_confirmed_dict[state] = state_train_c
        train_death_dict[state] = state_train_d

    return train_confirmed_dict, train_death_dict, valid_confirmed_dict, valid_death_dict

# %%
train_confirmed_dict, train_death_dict, valid_confirmed_dict, valid_death_dict = train_valid_split()
train_confirmed_dict["Alabama"].shape[0]
# Out:
# 203

# %%
def run_arima():
    predictions = []
    for state in states_names:
        state_data = pd.read_csv(DIR_TRAIN_BY_STATE + state + ".csv")
        
        mape_confirmed = 1e7
        pdq_confirmed = None
        model_confirmed = None

        mape_death = 1e7
        pdq_death = None
        model_death = None

        for pdq in pdq_candidates:
            mod = ARIMA(train_confirmed_dict[state], order=pdq, enforce_stationarity=False)
            f = mod.fit(method="statespace")
            pred_c = f.predict(start=train_confirmed_dict[state].shape[0], end=train_confirmed_dict[state].shape[0] + valid_confirmed_dict[state].shape[0] - 1)
            error = mape(np.array(pred_c.tolist()), valid_confirmed_dict[state])
            if error < mape_confirmed:
                print("Updating param: ", error, pdq)
                mape_confirmed = error
                pdq_confirmed = pdq

        print("Best parameter for ", state, "'s confirmed is PDQ: ", pdq_confirmed)
        model_confirmed = ARIMA(state_data['Confirmed'], order=pdq_confirmed, enforce_stationarity=False)

        for pdq in pdq_candidates:
            mod = ARIMA(train_death_dict[state], order=pdq, enforce_stationarity=False)

            f = mod.fit(method="statespace")
            pred_d = f.predict(start=train_death_dict[state].shape[0], end=train_death_dict[state].shape[0] + valid_death_dict[state].shape[0] - 1)
            error = mape(np.array(pred_d.tolist()), valid_death_dict[state])
            if error < mape_death:
                print("Updating param: ", error, pdq)
                mape_death = error
                pdq_death = pdq
        
        print("Best parameter for ", state, "'s death is PDQ: ", pdq_death)
        model_death = ARIMA(state_data['Deaths'], order=pdq_death, enforce_stationarity=False)

        fit_confirmed = model_confirmed.fit(method="statespace")
        predict_confirmed = fit_confirmed.predict(start=225, end=245)
        fit_death = model_death.fit(method="statespace")

        predict_death = fit_death.predict(start=225, end=245)
        predictions.append((np.around(predict_confirmed, decimals=0), np.around(predict_death, decimals=0)))

    return predictions

# %%
def run_seasonal_arima():
    predictions = []
    for state in states_names:
        state_data = pd.read_csv(DIR_TRAIN_BY_STATE + state + ".csv")

        mape_confirmed = 1e7
        pdq_confirmed = None
        seasonal_pdq_confirmed = None
        model_confirmed = None

        mape_death = 1e7
        pdq_death = None
        seasonal_pdq_death = None
        model_death = None

        for pdq in pdq_candidates:
            try:
                mod = SARIMAX(train_confirmed_dict[state], order=pdq,# seasonal_order=seasonal_pdq,
                              enforce_stationarity=False, enforce_invertibility=False)

                f = mod.fit(disp=False, method='powell')
                pred_c = f.predict(start=train_confirmed_dict[state].shape[0], end=train_confirmed_dict[state].shape[0] + valid_confirmed_dict[state].shape[0] - 1)
                error = mape(np.array(pred_c.tolist()), valid_confirmed_dict[state])
                if error < mape_confirmed:
                    print("Updating confirmed param: ", error, pdq)
                    mape_confirmed = error
                    pdq_confirmed = pdq
            except:
                continue
       
        print("Best parameter for ", state, "'s confirmed is PDQ: ", pdq_confirmed)
        model_confirmed = SARIMAX(state_data['Confirmed'], order=pdq_confirmed,# seasonal_order=seasonal_pdq_confirmed,
                                  enforce_stationarity=False, enforce_invertibility=False)

        for pdq in pdq_candidates:
                try:
                    mod = SARIMAX(train_death_dict[state], order=pdq,# seasonal_order=seasonal_pdq,
                                  enforce_stationarity=False, enforce_invertibility=False)
                    f = mod.fit(disp=False, method='powell')
                    pred_d = f.predict(start=train_death_dict[state].shape[0], end=train_death_dict[state].shape[0] + valid_death_dict[state].shape[0] - 1)
                    error = mape(np.array(pred_d.tolist()), valid_death_dict[state])
                    if error < mape_death:
                        print("Updating death param: ", error, pdq)
                        mape_death = error
                        pdq_death = pdq
                except:
                    continue
        
        print("Best parameter for ", state, "'s deaths is PDQ: ", pdq_death)
        model_death = SARIMAX(state_data['Deaths'],order=pdq_death,# seasonal_order=seasonal_pdq_death,
                                  enforce_stationarity=False, enforce_invertibility=False)

        fit_c = model_confirmed.fit(disp=False, method='powell')
        y_pred_confirmed = fit_c.predict(start=239, end=245)
        fit_d = model_death.fit(disp=False, method='powell')

        y_pred_deaths = fit_d.predict(start=239, end=245)
        predictions.append((np.around(y_pred_confirmed, decimals=0), np.around(y_pred_deaths, decimals=0)))

    return predictions

# %%
# predictions = run_arima()
predictions = run_seasonal_arima()

predictions
# Out:
# Updating confirmed param:  0.6774556777337909 (1, 1, 1)
# Updating confirmed param:  0.6769914314694178 (1, 1, 3)
# Updating confirmed param:  0.6751151804847361 (2, 1, 1)
# Updating confirmed param:  0.6683758927423774 (2, 1, 2)
# Updating confirmed param:  0.6675154099749339 (3, 1, 3)
# Updating confirmed param:  0.641834075566313 (4, 1, 3)
# Best parameter for  Alabama 's confirmed is PDQ:  (4, 1, 3)
# Updating death param:  2.0474580561732436 (1, 1, 1)
# Updating death param:  1.9806573099945355 (1, 1, 2)
# Updating death param:  1.9785982262792188 (1, 1, 3)
# Updating death param:  1.881865264048907 (2, 1, 2)
# Updating death param:  1.6226314745785977 (3, 1, 4)
# Best parameter for  Alabama 's deaths is PDQ:  (3, 1, 4)
# Updating confirmed param:  10.60378562451849 (1, 1, 1)
# Updating confirmed param:  9.29597159060175 (1, 1, 3)
# Updating confirmed param:  9.25385117652727 (1, 1, 4)
# Updating confirmed param:  8.288351586127307 (2, 1, 3)
# Updating confirmed param:  6.956529129539603 (4, 1, 1)
# Best parameter for  Alaska 's confirmed is PDQ:  (4, 1, 1)
# Updating death param:  4.744235530632836 (1, 1, 1)
# Updating death param:  2.176980440089391 (1, 1, 6)
# Best parameter for  Alaska 's deaths is PDQ:  (1, 1, 6)
# Updating confirmed param:  2.3540241611416155 (1, 1, 1)
# Updating confirmed param:  2.294586258311175 (1, 1, 3)
# Updating confirmed param:  2.170137310904642 (1, 1, 4)
# Updating confirmed param:  1.946051235820069 (1, 1, 5)
# Updating confirmed param:  1.6880499633146677 (1, 1, 7)
# Updating confirmed param:  0.9931407487920707 (4, 1, 3)
# Best parameter for  Arizona 's confirmed is PDQ:  (4, 1, 3)
# Updating death param:  1.426316908788099 (1, 1, 1)
# Updating death param:  1.3289589828968429 (1, 1, 3)
# Updating death param:  1.153614030086263 (1, 1, 4)
# Updating death param:  1.1286998424444228 (1, 1, 5)
# Updating death param:  1.110240425492581 (1, 1, 6)
# Updating death param:  0.8309595990300419 (1, 1, 7)
# Updating death param:  0.5663865900966369 (2, 1, 7)
# Updating death param:  0.553079449483353 (3, 1, 7)
# Best parameter for  Arizona 's deaths is PDQ:  (3, 1, 7)
# Updating confirmed param:  2.2068194242040295 (1, 1, 1)
# Updating confirmed param:  2.1933188594195854 (1, 1, 6)
# Updating confirmed param:  2.1752213756240857 (1, 1, 7)
# Updating confirmed param:  2.1516894996652502 (2, 1, 5)
# Updating confirmed param:  2.024914594495111 (2, 1, 7)
# Updating confirmed param:  1.5795209288868166 (3, 1, 2)
# Best parameter for  Arkansas 's confirmed is PDQ:  (3, 1, 2)
# Updating death param:  1.9878327453416098 (1, 1, 1)
# Updating death param:  1.6481395615294536 (1, 1, 3)
# Updating death param:  1.5452489128602716 (1, 1, 4)
# Updating death param:  1.2314242368583033 (1, 1, 5)
# Updating death param:  0.6201792617476857 (1, 1, 6)
# Best parameter for  Arkansas 's deaths is PDQ:  (1, 1, 6)
# Updating confirmed param:  2.8860246367170737 (1, 1, 1)
# Updating confirmed param:  2.826254704009464 (1, 1, 2)
# Updating confirmed param:  2.741326532967324 (1, 1, 4)
# Updating confirmed param:  2.719069974476783 (1, 1, 5)
# Updating confirmed param:  2.6696968447113614 (1, 1, 6)
# Updating confirmed param:  2.469847682693423 (3, 1, 4)
# Best parameter for  California 's confirmed is PDQ:  (3, 1, 4)
# Updating death param:  0.5674436229602295 (1, 1, 1)
# Updating death param:  0.35667846374807566 (1, 1, 4)
# Updating death param:  0.3474986669447476 (2, 1, 5)
# Updating death param:  0.26954528665718197 (2, 1, 7)
# Best parameter for  California 's deaths is PDQ:  (2, 1, 7)
# Updating confirmed param:  3.1191162578995333 (1, 1, 1)
# Updating confirmed param:  3.1075667403218614 (1, 1, 3)
# Updating confirmed param:  2.5972126380748106 (1, 1, 5)
# Updating confirmed param:  1.4952232438830708 (1, 1, 6)
# Updating confirmed param:  1.3401749195053203 (1, 1, 7)
# Updating confirmed param:  1.1592656307761113 (2, 1, 7)
# Updating confirmed param:  1.0511567488513478 (3, 1, 7)
# Best parameter for  Colorado 's confirmed is PDQ:  (3, 1, 7)
# Updating death param:  5.748253764381003 (1, 1, 1)
# Updating death param:  5.710167647422158 (1, 1, 5)
# Updating death param:  0.6743852373602216 (3, 1, 3)
# Best parameter for  Colorado 's deaths is PDQ:  (3, 1, 3)
# Updating confirmed param:  10.890391896723028 (1, 1, 1)
# Updating confirmed param:  9.12933608882202 (1, 1, 2)
# Updating confirmed param:  8.453603562611569 (1, 1, 3)
# Updating confirmed param:  7.858482180614211 (1, 1, 4)
# Updating confirmed param:  7.343943451510665 (1, 1, 5)
# Updating confirmed param:  7.028302468143653 (1, 1, 6)
# Updating confirmed param:  6.743562030279203 (2, 1, 6)
# Best parameter for  Connecticut 's confirmed is PDQ:  (2, 1, 6)
# Updating death param:  1.6842649505424685 (1, 1, 1)
# Updating death param:  1.1038925051292006 (1, 1, 4)
# Updating death param:  0.7516582309092901 (1, 1, 7)
# Best parameter for  Connecticut 's deaths is PDQ:  (1, 1, 7)
# Updating confirmed param:  4.264320271892707 (1, 1, 1)
# Updating confirmed param:  4.185522476751231 (1, 1, 2)
# Updating confirmed param:  4.138888875716564 (1, 1, 3)
# Updating confirmed param:  4.0673192570894825 (1, 1, 4)
# Updating confirmed param:  4.0639063460114855 (4, 1, 1)
# Best parameter for  Delaware 's confirmed is PDQ:  (4, 1, 1)
# Updating death param:  1.6986057627858562 (1, 1, 1)
# Updating death param:  1.4128076581572706 (3, 1, 1)
# Best parameter for  Delaware 's deaths is PDQ:  (3, 1, 1)
# Updating confirmed param:  2.611965611648143 (1, 1, 1)
# Updating confirmed param:  2.40404241008072 (1, 1, 4)
# Updating confirmed param:  2.3655247329427733 (1, 1, 5)
# Updating confirmed param:  2.3576712440249765 (2, 1, 6)
# Updating confirmed param:  2.073005590999191 (4, 1, 3)
# Best parameter for  Florida 's confirmed is PDQ:  (4, 1, 3)
# Updating death param:  0.48997883725670516 (1, 1, 1)
# Updating death param:  0.3910097051477065 (2, 1, 3)
# Updating death param:  0.33060018090794957 (3, 1, 3)
# Updating death param:  0.27248503358633563 (3, 1, 4)
# Best parameter for  Florida 's deaths is PDQ:  (3, 1, 4)
# Updating confirmed param:  7.762517807477237 (1, 1, 1)
# Updating confirmed param:  7.670465460686975 (1, 1, 2)
# Updating confirmed param:  7.651220248304136 (1, 1, 5)
# Updating confirmed param:  7.556845805796514 (1, 1, 6)
# Updating confirmed param:  7.537382523072917 (1, 1, 7)
# Updating confirmed param:  5.561538607473493 (2, 1, 1)
# Best parameter for  Georgia 's confirmed is PDQ:  (2, 1, 1)
# Updating death param:  5.483826713698933 (1, 1, 1)
# Updating death param:  5.467329814624103 (2, 1, 2)
# Updating death param:  5.455375725517831 (3, 1, 2)
# Updating death param:  5.45325668094897 (3, 1, 3)
# Updating death param:  5.426267302204547 (3, 1, 4)
# Updating death param:  5.216439824105038 (4, 1, 3)
# Best parameter for  Georgia 's deaths is PDQ:  (4, 1, 3)
# Updating confirmed param:  2.790427921594587 (1, 1, 1)
# Updating confirmed param:  2.750272026938451 (1, 1, 2)
# Updating confirmed param:  2.717861685814799 (1, 1, 3)
# Updating confirmed param:  2.708632266565567 (3, 1, 2)
# Best parameter for  Hawaii 's confirmed is PDQ:  (3, 1, 2)
# Updating death param:  11.65718573574773 (1, 1, 1)
# Updating death param:  11.390704341108897 (1, 1, 5)
# Updating death param:  10.42730661393382 (1, 1, 7)
# Updating death param:  1.8226614226719002 (3, 1, 1)
# Best parameter for  Hawaii 's deaths is PDQ:  (3, 1, 1)
# Updating confirmed param:  2.410543448407516 (1, 1, 1)
# Updating confirmed param:  2.2706562655303175 (1, 1, 2)
# Updating confirmed param:  2.267167021569112 (1, 1, 3)
# Updating confirmed param:  2.2415621798043768 (2, 1, 1)
# Updating confirmed param:  2.0262222023871987 (3, 1, 2)
# Best parameter for  Idaho 's confirmed is PDQ:  (3, 1, 2)
# Updating death param:  3.084064028288478 (1, 1, 1)
# Updating death param:  2.3543928926447757 (1, 1, 2)
# Updating death param:  1.4080421054048236 (1, 1, 3)
# Updating death param:  1.394869525509665 (1, 1, 4)
# Updating death param:  1.3890894038059087 (2, 1, 6)
# Updating death param:  1.3599098390175484 (2, 1, 7)
# Updating death param:  1.2882679655722709 (4, 1, 7)
# Best parameter for  Idaho 's deaths is PDQ:  (4, 1, 7)
# Updating confirmed param:  3.0529193862913275 (1, 1, 1)
# Updating confirmed param:  2.860694997288744 (1, 1, 5)
# Updating confirmed param:  2.823535184357736 (1, 1, 6)
# Updating confirmed param:  2.6915879795633604 (2, 1, 1)
# Updating confirmed param:  2.591307934227475 (4, 1, 1)
# Best parameter for  Illinois 's confirmed is PDQ:  (4, 1, 1)
# Updating death param:  3.7929740208973945 (1, 1, 1)
# Updating death param:  3.3843497138070333 (1, 1, 4)
# Updating death param:  3.352701285507554 (1, 1, 5)
# Updating death param:  3.2577296647015737 (1, 1, 7)
# Best parameter for  Illinois 's deaths is PDQ:  (1, 1, 7)
# Updating confirmed param:  3.712871722445235 (1, 1, 1)
# Best parameter for  Indiana 's confirmed is PDQ:  (1, 1, 1)
# Updating death param:  3.650356147616493 (1, 1, 1)
# Updating death param:  2.362762110419291 (1, 1, 3)
# Updating death param:  1.8636747058529957 (1, 1, 5)
# Updating death param:  1.6388536486968 (2, 1, 1)
# Updating death param:  1.2851402736374429 (2, 1, 5)
# Best parameter for  Indiana 's deaths is PDQ:  (2, 1, 5)
# Updating confirmed param:  6.2840822820016795 (1, 1, 1)
# Updating confirmed param:  2.0168341961576997 (2, 1, 6)
# Best parameter for  Iowa 's confirmed is PDQ:  (2, 1, 6)
# Updating death param:  4.724807295198071 (1, 1, 1)
# Updating death param:  4.073577995481658 (1, 1, 3)
# Updating death param:  3.7541529830451053 (1, 1, 4)
# Updating death param:  3.3298480451279246 (1, 1, 5)
# Updating death param:  3.208725099806151 (1, 1, 6)
# Updating death param:  3.0674389077796906 (1, 1, 7)
# Updating death param:  2.9944171533819395 (2, 1, 7)
# Updating death param:  2.9225026745284746 (3, 1, 7)
# Best parameter for  Iowa 's deaths is PDQ:  (3, 1, 7)
# Updating confirmed param:  11.406636543823929 (1, 1, 1)
# Updating confirmed param:  10.89468055506613 (1, 1, 2)
# Updating confirmed param:  10.45375504162347 (2, 1, 1)
# Updating confirmed param:  10.083212772335402 (2, 1, 3)
# Updating confirmed param:  10.055179172990577 (3, 1, 1)
# Updating confirmed param:  8.948786094338391 (4, 1, 3)
# Best parameter for  Kansas 's confirmed is PDQ:  (4, 1, 3)
# Updating death param:  2.9537096208529237 (1, 1, 1)
# Updating death param:  2.8964711982553575 (1, 1, 4)
# Updating death param:  2.4508044151210115 (1, 1, 5)
# Updating death param:  2.283633572820959 (3, 1, 2)
# Best parameter for  Kansas 's deaths is PDQ:  (3, 1, 2)
# Updating confirmed param:  1.1406112754779134 (1, 1, 1)
# Updating confirmed param:  1.012237990581587 (1, 1, 3)
# Updating confirmed param:  0.9957839961161227 (3, 1, 1)
# Updating confirmed param:  0.9619249305721007 (3, 1, 4)
# Best parameter for  Kentucky 's confirmed is PDQ:  (3, 1, 4)
# Updating death param:  0.9796017853768161 (1, 1, 1)
# Updating death param:  0.8665627808853934 (3, 1, 4)
# Updating death param:  0.8617000169700912 (4, 1, 7)
# Best parameter for  Kentucky 's deaths is PDQ:  (4, 1, 7)
# Updating confirmed param:  5.401632544736324 (1, 1, 1)
# Updating confirmed param:  5.394994131929322 (1, 1, 2)
# Updating confirmed param:  5.3457293086557085 (2, 1, 4)
# Updating confirmed param:  5.340261255429701 (3, 1, 3)
# Updating confirmed param:  5.129944322538801 (3, 1, 6)
# Updating confirmed param:  5.096987818944484 (4, 1, 6)
# Best parameter for  Louisiana 's confirmed is PDQ:  (4, 1, 6)
# Updating death param:  0.9694525861245504 (1, 1, 1)
# Updating death param:  0.8823645432207409 (1, 1, 2)
# Updating death param:  0.6745666279932353 (1, 1, 4)
# Updating death param:  0.5961957877867265 (1, 1, 5)
# Updating death param:  0.5763389404651006 (1, 1, 6)
# Updating death param:  0.5034275582992096 (1, 1, 7)
# Updating death param:  0.4188006136364143 (4, 1, 3)
# Best parameter for  Louisiana 's deaths is PDQ:  (4, 1, 3)
# Updating confirmed param:  10.183214493778827 (1, 1, 1)
# Updating confirmed param:  10.001171621341774 (1, 1, 2)
# Updating confirmed param:  9.495024502701822 (1, 1, 3)
# Updating confirmed param:  9.213819540177054 (1, 1, 4)
# Updating confirmed param:  8.114221150521047 (1, 1, 5)
# Updating confirmed param:  7.97042658747983 (3, 1, 5)
# Updating confirmed param:  7.625578367337048 (4, 1, 5)
# Best parameter for  Maine 's confirmed is PDQ:  (4, 1, 5)
# Updating death param:  7.039086381727623 (1, 1, 1)
# Updating death param:  6.987035586217659 (1, 1, 2)
# Updating death param:  6.922416238488256 (1, 1, 3)
# Updating death param:  6.825230524274049 (2, 1, 3)
# Updating death param:  6.812965568069402 (2, 1, 4)
# Updating death param:  6.806442727580814 (3, 1, 4)
# Updating death param:  6.79724323698866 (4, 1, 3)
# Best parameter for  Maine 's deaths is PDQ:  (4, 1, 3)
# Updating confirmed param:  3.4984135445614353 (1, 1, 1)
# Updating confirmed param:  3.444523282393064 (1, 1, 4)
# Updating confirmed param:  3.1794141981112647 (1, 1, 5)
# Updating confirmed param:  2.9206730420683185 (1, 1, 6)
# Updating confirmed param:  2.721163129710346 (2, 1, 6)
# Best parameter for  Maryland 's confirmed is PDQ:  (2, 1, 6)
# Updating death param:  1.2447180527494495 (1, 1, 1)
# Updating death param:  0.9597530244320487 (1, 1, 2)
# Updating death param:  0.9426815396084726 (1, 1, 4)
# Updating death param:  0.9198302123865493 (1, 1, 5)
# Updating death param:  0.9131781669285797 (2, 1, 5)
# Updating death param:  0.8842917085746219 (3, 1, 2)
# Updating death param:  0.8513352904333314 (4, 1, 3)
# Best parameter for  Maryland 's deaths is PDQ:  (4, 1, 3)
# Updating confirmed param:  6.441703608419896 (1, 1, 1)
# Updating confirmed param:  6.3765144608465 (1, 1, 5)
# Updating confirmed param:  6.272133217888282 (1, 1, 6)
# Updating confirmed param:  6.174536761697624 (3, 1, 1)
# Best parameter for  Massachusetts 's confirmed is PDQ:  (3, 1, 1)
# Updating death param:  0.665363197058479 (1, 1, 1)
# Updating death param:  0.3911205645544594 (1, 1, 2)
# Updating death param:  0.3094009833381717 (4, 1, 1)
# Best parameter for  Massachusetts 's deaths is PDQ:  (4, 1, 1)
# Updating confirmed param:  6.46917569055923 (1, 1, 1)
# Updating confirmed param:  5.154294341322484 (1, 1, 2)
# Updating confirmed param:  5.0847647224905685 (1, 1, 3)
# Updating confirmed param:  4.923177570687389 (1, 1, 4)
# Updating confirmed param:  4.698284359828133 (1, 1, 5)
# Updating confirmed param:  4.154904343121588 (4, 1, 3)
# Best parameter for  Michigan 's confirmed is PDQ:  (4, 1, 3)
# Updating death param:  4.533331660440581 (1, 1, 1)
# Updating death param:  4.3583411707445565 (1, 1, 2)
# Updating death param:  4.2145110040305305 (1, 1, 3)
# Updating death param:  3.9377369170718 (1, 1, 4)
# Updating death param:  3.9244947655204303 (1, 1, 6)
# Updating death param:  3.773762822336716 (3, 1, 7)
# Best parameter for  Michigan 's deaths is PDQ:  (3, 1, 7)
# Updating confirmed param:  6.90678674965079 (1, 1, 1)
# Updating confirmed param:  6.513957962895295 (1, 1, 6)
# Updating confirmed param:  6.486494920722991 (2, 1, 7)
# Updating confirmed param:  6.083129438512172 (3, 1, 5)
# Updating confirmed param:  5.376778426520854 (3, 1, 6)
# Updating confirmed param:  4.577658677594608 (4, 1, 6)
# Best parameter for  Minnesota 's confirmed is PDQ:  (4, 1, 6)
# Updating death param:  4.5071354198685025 (1, 1, 1)
# Updating death param:  4.452775902245063 (1, 1, 2)
# Updating death param:  4.300214966830231 (1, 1, 3)
# Updating death param:  3.994810540606021 (1, 1, 4)
# Updating death param:  3.9790655339598273 (1, 1, 7)
# Updating death param:  3.966658091659191 (2, 1, 4)
# Updating death param:  3.945702166173843 (3, 1, 3)
# Best parameter for  Minnesota 's deaths is PDQ:  (3, 1, 3)
# Updating confirmed param:  1.2105830171736465 (1, 1, 1)
# Updating confirmed param:  1.0315104729610307 (1, 1, 4)
# Updating confirmed param:  1.0137630829400888 (1, 1, 5)
# Updating confirmed param:  1.0005892012720485 (1, 1, 6)
# Updating confirmed param:  0.9959828009079993 (2, 1, 6)
# Updating confirmed param:  0.9916627437359329 (3, 1, 3)
# Best parameter for  Mississippi 's confirmed is PDQ:  (3, 1, 3)
# Updating death param:  0.9414558844248038 (1, 1, 1)
# Updating death param:  0.9383945106688907 (2, 1, 4)
# Updating death param:  0.9071911452901508 (3, 1, 2)
# Best parameter for  Mississippi 's deaths is PDQ:  (3, 1, 2)
# Updating confirmed param:  6.140184357679101 (1, 1, 1)
# Updating confirmed param:  5.93462699990251 (1, 1, 2)
# Updating confirmed param:  5.80828194056715 (2, 1, 3)
# Updating confirmed param:  5.072349206036209 (3, 1, 2)
# Best parameter for  Missouri 's confirmed is PDQ:  (3, 1, 2)
# Updating death param:  4.415470349269763 (1, 1, 1)
# Updating death param:  4.154560548219859 (1, 1, 2)
# Updating death param:  3.766468910452873 (1, 1, 3)
# Updating death param:  3.759644234082445 (1, 1, 4)
# Updating death param:  3.6191293315495665 (1, 1, 5)
# Updating death param:  3.6068650032242346 (1, 1, 6)
# Updating death param:  3.319241731958697 (1, 1, 7)
# Updating death param:  3.2197334279871694 (3, 1, 7)
# Best parameter for  Missouri 's deaths is PDQ:  (3, 1, 7)
# Updating confirmed param:  4.834775497822874 (1, 1, 1)
# Updating confirmed param:  4.7797477230822745 (1, 1, 2)
# Updating confirmed param:  3.3348549770205476 (1, 1, 4)
# Updating confirmed param:  3.172474064639552 (1, 1, 5)
# Updating confirmed param:  3.169835821750818 (1, 1, 6)
# Updating confirmed param:  1.5261121679600644 (1, 1, 7)
# Updating confirmed param:  1.4233356436472668 (2, 1, 7)
# Best parameter for  Montana 's confirmed is PDQ:  (2, 1, 7)
# Updating death param:  20.120697689798998 (1, 1, 1)
# Updating death param:  19.995903165244922 (2, 1, 3)
# Updating death param:  18.596628633431518 (3, 1, 3)
# Best parameter for  Montana 's deaths is PDQ:  (3, 1, 3)
# Updating confirmed param:  6.084775164143013 (1, 1, 1)
# Updating confirmed param:  5.644351279208759 (1, 1, 7)
# Updating confirmed param:  5.297615686882775 (2, 1, 7)
# Best parameter for  Nebraska 's confirmed is PDQ:  (2, 1, 7)
# Updating death param:  4.438710227303733 (1, 1, 1)
# Updating death param:  4.436293493326612 (1, 1, 2)
# Updating death param:  3.286600249607182 (1, 1, 3)
# Updating death param:  2.5970246215586466 (1, 1, 4)
# Updating death param:  2.5548844565716378 (2, 1, 7)
# Updating death param:  2.437281353476589 (3, 1, 7)
# Updating death param:  2.364519903090267 (4, 1, 7)
# Best parameter for  Nebraska 's deaths is PDQ:  (4, 1, 7)
# Updating confirmed param:  3.183432125960364 (1, 1, 1)
# Updating confirmed param:  3.0229530982745154 (2, 1, 1)
# Updating confirmed param:  3.0023612518175757 (4, 1, 3)
# Best parameter for  Nevada 's confirmed is PDQ:  (4, 1, 3)
# Updating death param:  2.8291533209247364 (1, 1, 1)
# Updating death param:  2.8110891341028807 (1, 1, 2)
# Updating death param:  2.7973886175445717 (4, 1, 1)
# Best parameter for  Nevada 's deaths is PDQ:  (4, 1, 1)
# Updating confirmed param:  8.39590196547302 (1, 1, 1)
# Updating confirmed param:  8.006790154093075 (1, 1, 2)
# Updating confirmed param:  6.7536672337126475 (1, 1, 4)
# Updating confirmed param:  6.219547891627821 (1, 1, 6)
# Updating confirmed param:  5.714836921533093 (3, 1, 4)
# Best parameter for  New Hampshire 's confirmed is PDQ:  (3, 1, 4)
# Updating death param:  0.469919238748091 (1, 1, 1)
# Updating death param:  0.45968512233206377 (1, 1, 2)
# Updating death param:  0.45353982798123527 (4, 1, 3)
# Best parameter for  New Hampshire 's deaths is PDQ:  (4, 1, 3)
# Updating confirmed param:  5.722250343734902 (1, 1, 1)
# Updating confirmed param:  5.145653928863815 (1, 1, 2)
# Updating confirmed param:  5.130606657738271 (3, 1, 1)
# Best parameter for  New Jersey 's confirmed is PDQ:  (3, 1, 1)
# Updating death param:  0.7217360626324169 (1, 1, 1)
# Updating death param:  0.678318365181394 (1, 1, 6)
# Best parameter for  New Jersey 's deaths is PDQ:  (1, 1, 6)
# Updating confirmed param:  5.466666343371425 (1, 1, 1)
# Best parameter for  New Mexico 's confirmed is PDQ:  (1, 1, 1)
# Updating death param:  6.611305477707363 (1, 1, 1)
# Updating death param:  6.46274525025568 (1, 1, 2)
# Updating death param:  6.109802133226153 (1, 1, 3)
# Updating death param:  5.715054562352179 (1, 1, 4)
# Updating death param:  5.534521066889331 (1, 1, 5)
# Updating death param:  5.402473157365868 (1, 1, 6)
# Updating death param:  5.19356911910801 (1, 1, 7)
# Best parameter for  New Mexico 's deaths is PDQ:  (1, 1, 7)
# Updating confirmed param:  4.655934892546764 (1, 1, 1)
# Updating confirmed param:  4.579358230928426 (1, 1, 2)
# Updating confirmed param:  4.083220729409044 (1, 1, 3)
# Updating confirmed param:  3.479729863807247 (1, 1, 5)
# Updating confirmed param:  3.164951736468731 (1, 1, 7)
# Updating confirmed param:  2.8974331423740542 (4, 1, 7)
# Best parameter for  New York 's confirmed is PDQ:  (4, 1, 7)
# Updating death param:  0.972510335958044 (1, 1, 1)
# Updating death param:  0.9444879942303714 (1, 1, 2)
# Updating death param:  0.6901799679844539 (1, 1, 3)
# Updating death param:  0.6754398011334022 (1, 1, 6)
# Updating death param:  0.6178656125274186 (1, 1, 7)
# Updating death param:  0.5305705668094409 (2, 1, 6)
# Updating death param:  0.49889926643672267 (4, 1, 7)
# Best parameter for  New York 's deaths is PDQ:  (4, 1, 7)
# Updating confirmed param:  0.5145840474355835 (1, 1, 1)
# Updating confirmed param:  0.5022466474830802 (1, 1, 2)
# Updating confirmed param:  0.4784520938368777 (1, 1, 4)
# Updating confirmed param:  0.46517548801197706 (2, 1, 4)
# Updating confirmed param:  0.46450025392716704 (4, 1, 5)
# Updating confirmed param:  0.46381114062504614 (4, 1, 6)
# Updating confirmed param:  0.4599501495958632 (4, 1, 7)
# Best parameter for  North Carolina 's confirmed is PDQ:  (4, 1, 7)
# Updating death param:  0.7453434659134425 (1, 1, 1)
# Updating death param:  0.7042211663617393 (2, 1, 5)
# Updating death param:  0.6608529781116405 (4, 1, 5)
# Updating death param:  0.540383926922864 (4, 1, 6)
# Best parameter for  North Carolina 's deaths is PDQ:  (4, 1, 6)
# Updating confirmed param:  3.0860169675599094 (1, 1, 1)
# Updating confirmed param:  2.165419346648238 (1, 1, 2)
# Updating confirmed param:  1.317181046198714 (1, 1, 3)
# Best parameter for  North Dakota 's confirmed is PDQ:  (1, 1, 3)
# Updating death param:  1.4828827001977316 (1, 1, 1)
# Updating death param:  1.0552027537081816 (1, 1, 7)
# Best parameter for  North Dakota 's deaths is PDQ:  (1, 1, 7)
# Updating confirmed param:  6.468300589518837 (1, 1, 1)
# Updating confirmed param:  6.090604889090116 (2, 1, 1)
# Best parameter for  Ohio 's confirmed is PDQ:  (2, 1, 1)
# Updating death param:  3.256556914167244 (1, 1, 1)
# Updating death param:  3.2479500976801496 (1, 1, 2)
# Updating death param:  3.0547702552796943 (1, 1, 3)
# Updating death param:  2.889853963089678 (1, 1, 4)
# Updating death param:  2.663305917245057 (1, 1, 5)
# Updating death param:  2.497571299503929 (2, 1, 5)
# Best parameter for  Ohio 's deaths is PDQ:  (2, 1, 5)
# Updating confirmed param:  5.586202854011735 (1, 1, 1)
# Updating confirmed param:  5.309843612049966 (1, 1, 2)
# Updating confirmed param:  5.269627469455225 (3, 1, 4)
# Updating confirmed param:  5.249510474280086 (3, 1, 5)
# Updating confirmed param:  4.744473460746911 (4, 1, 3)
# Best parameter for  Oklahoma 's confirmed is PDQ:  (4, 1, 3)
# Updating death param:  0.5562870433476992 (1, 1, 1)
# Updating death param:  0.5538562833824587 (2, 1, 4)
# Updating death param:  0.5135604499794614 (3, 1, 1)
# Best parameter for  Oklahoma 's deaths is PDQ:  (3, 1, 1)
# Updating confirmed param:  5.850617049112485 (1, 1, 1)
# Updating confirmed param:  5.614051941837209 (1, 1, 2)
# Updating confirmed param:  5.090560161553239 (1, 1, 3)
# Updating confirmed param:  4.7974188823046795 (1, 1, 4)
# Updating confirmed param:  4.794269827794921 (2, 1, 4)
# Updating confirmed param:  4.77986492958133 (2, 1, 6)
# Updating confirmed param:  4.7587831747630664 (4, 1, 1)
# Best parameter for  Oregon 's confirmed is PDQ:  (4, 1, 1)
# Updating death param:  0.980416564459271 (1, 1, 1)
# Updating death param:  0.9635826582050507 (1, 1, 2)
# Updating death param:  0.8072038694709162 (1, 1, 3)
# Updating death param:  0.7258281046118927 (1, 1, 4)
# Updating death param:  0.7234284316689732 (1, 1, 6)
# Updating death param:  0.7063805164834378 (1, 1, 7)
# Updating death param:  0.7007374937214644 (2, 1, 7)
# Updating death param:  0.6876996471369601 (3, 1, 7)
# Updating death param:  0.6723259053566288 (4, 1, 7)
# Best parameter for  Oregon 's deaths is PDQ:  (4, 1, 7)
# Updating confirmed param:  5.95729355660976 (1, 1, 1)
# Updating confirmed param:  5.712468194759703 (1, 1, 2)
# Updating confirmed param:  5.113579206171814 (1, 1, 3)
# Updating confirmed param:  4.91743169688757 (1, 1, 4)
# Updating confirmed param:  4.653306259271963 (1, 1, 5)
# Updating confirmed param:  4.498559778387659 (1, 1, 6)
# Updating confirmed param:  4.084799043382299 (4, 1, 3)
# Best parameter for  Pennsylvania 's confirmed is PDQ:  (4, 1, 3)
# Updating death param:  2.9896918885533763 (1, 1, 1)
# Updating death param:  2.410696126945909 (1, 1, 5)
# Updating death param:  2.221214617207476 (1, 1, 7)
# Updating death param:  1.6586161402253805 (2, 1, 6)
# Best parameter for  Pennsylvania 's deaths is PDQ:  (2, 1, 6)
# Updating confirmed param:  8.866565264916847 (1, 1, 1)
# Updating confirmed param:  6.377057252183256 (1, 1, 3)
# Updating confirmed param:  5.584260610704412 (1, 1, 6)
# Updating confirmed param:  5.4654564261557885 (4, 1, 5)
# Best parameter for  Rhode Island 's confirmed is PDQ:  (4, 1, 5)
# Updating death param:  1.233038728526294 (1, 1, 1)
# Updating death param:  1.2136264610769372 (1, 1, 3)
# Updating death param:  1.1977540563323275 (1, 1, 6)
# Updating death param:  0.9107697572941041 (1, 1, 7)
# Updating death param:  0.8904225454293822 (2, 1, 7)
# Best parameter for  Rhode Island 's deaths is PDQ:  (2, 1, 7)
# Updating confirmed param:  1.3532760676435152 (1, 1, 1)
# Updating confirmed param:  1.2435840775090008 (1, 1, 4)
# Updating confirmed param:  1.1969891343223793 (1, 1, 5)
# Updating confirmed param:  0.7295726080416387 (3, 1, 3)
# Updating confirmed param:  0.7192076505951744 (4, 1, 3)
# Best parameter for  South Carolina 's confirmed is PDQ:  (4, 1, 3)
# Updating death param:  2.0614035106261572 (1, 1, 1)
# Updating death param:  2.057475364485243 (1, 1, 2)
# Updating death param:  2.056552487594434 (1, 1, 3)
# Updating death param:  2.032262829750854 (1, 1, 4)
# Updating death param:  1.999547456466473 (1, 1, 5)
# Updating death param:  1.9423025075938432 (1, 1, 6)
# Updating death param:  1.914975259054953 (1, 1, 7)
# Updating death param:  1.9126781729223854 (3, 1, 2)
# Updating death param:  1.2212100915679722 (4, 1, 1)
# Best parameter for  South Carolina 's deaths is PDQ:  (4, 1, 1)
# Updating confirmed param:  7.11030191460143 (1, 1, 1)
# Updating confirmed param:  6.362807067908567 (1, 1, 2)
# Updating confirmed param:  5.855084197197226 (1, 1, 3)
# Updating confirmed param:  5.735419476291385 (1, 1, 6)
# Updating confirmed param:  5.628006719702523 (2, 1, 3)
# Updating confirmed param:  5.546488499958061 (4, 1, 4)
# Best parameter for  South Dakota 's confirmed is PDQ:  (4, 1, 4)
# Updating death param:  5.140484115688535 (1, 1, 1)
# Best parameter for  South Dakota 's deaths is PDQ:  (1, 1, 1)
# Updating confirmed param:  3.2263581454753214 (1, 1, 1)
# Updating confirmed param:  3.2086406606137277 (1, 1, 3)
# Updating confirmed param:  2.680948613728829 (1, 1, 7)
# Updating confirmed param:  2.6667392081916605 (2, 1, 7)
# Best parameter for  Tennessee 's confirmed is PDQ:  (2, 1, 7)
# Updating death param:  1.0215982993496795 (1, 1, 1)
# Updating death param:  0.9870608924443178 (1, 1, 3)
# Updating death param:  0.9862537359902832 (4, 1, 3)
# Best parameter for  Tennessee 's deaths is PDQ:  (4, 1, 3)
# Updating confirmed param:  2.2864389207426448 (1, 1, 1)
# Updating confirmed param:  2.1412351498918842 (1, 1, 3)
# Updating confirmed param:  1.9468404499063163 (1, 1, 4)
# Updating confirmed param:  1.9016098469062774 (1, 1, 5)
# Updating confirmed param:  1.9012897396485544 (1, 1, 6)
# Updating confirmed param:  1.8724868600548001 (2, 1, 4)
# Updating confirmed param:  1.8532180142034556 (2, 1, 6)
# Updating confirmed param:  1.8106558650965467 (3, 1, 6)
# Best parameter for  Texas 's confirmed is PDQ:  (3, 1, 6)
# Updating death param:  1.466554457270036 (1, 1, 1)
# Updating death param:  1.0372886986442458 (1, 1, 5)
# Updating death param:  1.0291872098593142 (2, 1, 6)
# Best parameter for  Texas 's deaths is PDQ:  (2, 1, 6)
# Updating confirmed param:  5.895245325031134 (1, 1, 1)
# Updating confirmed param:  4.213841601492926 (1, 1, 2)
# Updating confirmed param:  4.059753757915967 (1, 1, 4)
# Updating confirmed param:  3.994739077975674 (1, 1, 5)
# Updating confirmed param:  3.9772958044724036 (2, 1, 3)
# Updating confirmed param:  3.8952961009337392 (2, 1, 4)
# Best parameter for  Utah 's confirmed is PDQ:  (2, 1, 4)
# Updating death param:  4.3998026985988865 (1, 1, 1)
# Updating death param:  4.34537227406344 (1, 1, 2)
# Updating death param:  3.701282684151397 (1, 1, 3)
# Updating death param:  3.5173532086810337 (1, 1, 4)
# Updating death param:  3.4580587994764587 (1, 1, 5)
# Updating death param:  3.3238329787116996 (1, 1, 6)
# Best parameter for  Utah 's deaths is PDQ:  (1, 1, 6)
# Updating confirmed param:  10.578946563257544 (1, 1, 1)
# Updating confirmed param:  10.507570551756874 (1, 1, 3)
# Updating confirmed param:  10.376743117257297 (1, 1, 6)
# Updating confirmed param:  10.1418520866513 (1, 1, 7)
# Updating confirmed param:  10.072336689823036 (3, 1, 7)
# Updating confirmed param:  2.8664200591661118 (4, 1, 3)
# Best parameter for  Vermont 's confirmed is PDQ:  (4, 1, 3)
# Updating death param:  2.6461043501157304 (1, 1, 1)
# Updating death param:  2.3542226761813856 (1, 1, 2)
# Updating death param:  2.237668750098925 (1, 1, 4)
# Updating death param:  2.237236764839866 (1, 1, 5)
# Updating death param:  2.2372306989714414 (2, 1, 7)
# Updating death param:  2.216343265105747 (3, 1, 4)
# Best parameter for  Vermont 's deaths is PDQ:  (3, 1, 4)
# Updating confirmed param:  0.7701555955650048 (1, 1, 1)
# Updating confirmed param:  0.5127066895875932 (1, 1, 4)
# Updating confirmed param:  0.49823958251411476 (1, 1, 5)
# Updating confirmed param:  0.49314494656539365 (1, 1, 6)
# Updating confirmed param:  0.48844387996484506 (1, 1, 7)
# Updating confirmed param:  0.48673917073847667 (3, 1, 4)
# Updating confirmed param:  0.48383541807077696 (3, 1, 5)
# Best parameter for  Virginia 's confirmed is PDQ:  (3, 1, 5)
# Updating death param:  0.839312251547977 (1, 1, 1)
# Updating death param:  0.6966674706867262 (2, 1, 1)
# Best parameter for  Virginia 's deaths is PDQ:  (2, 1, 1)
# Updating confirmed param:  5.523002820756234 (1, 1, 1)
# Updating confirmed param:  5.439014702477059 (1, 1, 2)
# Updating confirmed param:  5.401540908680686 (3, 1, 2)
# Updating confirmed param:  5.38309481908263 (4, 1, 2)
# Updating confirmed param:  5.3489116666090695 (4, 1, 3)
# Best parameter for  Washington 's confirmed is PDQ:  (4, 1, 3)
# Updating death param:  2.1630911438631597 (1, 1, 1)
# Updating death param:  1.9422228624724467 (1, 1, 3)
# Updating death param:  1.726547919315101 (1, 1, 4)
# Updating death param:  1.4673443249174192 (1, 1, 5)
# Updating death param:  1.3790551830713722 (1, 1, 7)
# Updating death param:  1.3696278867555778 (2, 1, 7)
# Updating death param:  1.3628971450150473 (3, 1, 7)
# Best parameter for  Washington 's deaths is PDQ:  (3, 1, 7)
# Updating confirmed param:  4.434751721531029 (1, 1, 1)
# Updating confirmed param:  4.317595435106287 (1, 1, 4)
# Updating confirmed param:  4.310224827020047 (1, 1, 5)
# Updating confirmed param:  4.232829178098066 (1, 1, 6)
# Updating confirmed param:  4.209748882688274 (2, 1, 4)
# Updating confirmed param:  4.183108943293036 (3, 1, 6)
# Updating confirmed param:  3.7113861372907473 (4, 1, 1)
# Best parameter for  West Virginia 's confirmed is PDQ:  (4, 1, 1)
# Updating death param:  7.139275914312113 (1, 1, 1)
# Updating death param:  6.9963949918073105 (1, 1, 2)
# Updating death param:  6.9764527601746655 (1, 1, 4)
# Updating death param:  6.935346704236103 (1, 1, 5)
# Updating death param:  6.912264284424895 (3, 1, 3)
# Updating death param:  6.689183905499646 (4, 1, 3)
# Best parameter for  West Virginia 's deaths is PDQ:  (4, 1, 3)
# Updating confirmed param:  1.6337524480332568 (1, 1, 1)
# Updating confirmed param:  1.443302526338004 (1, 1, 2)
# Updating confirmed param:  1.0168300226605613 (1, 1, 5)
# Updating confirmed param:  0.7635505973995308 (2, 1, 1)
# Best parameter for  Wisconsin 's confirmed is PDQ:  (2, 1, 1)
# Updating death param:  1.8938622551438817 (1, 1, 1)
# Updating death param:  1.849902742484669 (1, 1, 2)
# Updating death param:  1.8199021963765005 (2, 1, 2)
# Updating death param:  1.8060035171263464 (3, 1, 2)
# Best parameter for  Wisconsin 's deaths is PDQ:  (3, 1, 2)
# Updating confirmed param:  4.344972373325315 (1, 1, 1)
# Updating confirmed param:  3.1113315410774454 (1, 1, 2)
# Best parameter for  Wyoming 's confirmed is PDQ:  (1, 1, 2)
# Updating death param:  19.349328937574757 (1, 1, 1)
# Updating death param:  10.259820552780075 (1, 1, 2)
# Updating death param:  9.247456761436377 (1, 1, 3)
# Updating death param:  7.433906350021761 (1, 1, 6)
# Updating death param:  5.650609295755156 (2, 1, 6)
# Updating death param:  4.985578053718412 (3, 1, 4)
# Best parameter for  Wyoming 's deaths is PDQ:  (3, 1, 4)
# [(239    261321.0
#   240    262865.0
#   241    264413.0
#   242    265964.0
#   243    267518.0
#   244    269077.0
#   245    270638.0
#   dtype: float64,
#   239    5208.0
#   240    5249.0
#   241    5291.0
#   242    5333.0
#   243    5375.0
#   244    5417.0
#   245    5460.0
#   dtype: float64),
#  (239    12366.0
#   240    12444.0
#   241    12522.0
#   242    12600.0
#   243    12678.0
#   244    12757.0
#   245    12836.0
#   dtype: float64,
#   239    282.0
#   240    289.0
#   241    295.0
#   242    301.0
#   243    308.0
#   244    315.0
#   245    322.0
#   dtype: float64),
#  (239    93959.0
#   240    93375.0
#   241    92855.0
#   242    92399.0
#   243    92010.0
#   244    91688.0
#   245    91434.0
#   dtype: float64,
#   239    6158.0
#   240    6160.0
#   241    6163.0
#   242    6165.0
#   243    6167.0
#   244    6169.0
#   245    6171.0
#   dtype: float64),
#  (239    73771.0
#   240    73793.0
#   241    73814.0
#   242    73835.0
#   243    73855.0
#   244    73875.0
#   245    73894.0
#   dtype: float64,
#   239    4275.0
#   240    4348.0
#   241    4422.0
#   242    4497.0
#   243    4573.0
#   244    4651.0
#   245    4730.0
#   dtype: float64),
#  (239    1333327.0
#   240    1340192.0
#   241    1347069.0
#   242    1353956.0
#   243    1360855.0
#   244    1367765.0
#   245    1374687.0
#   dtype: float64,
#   239    23951.0
#   240    24068.0
#   241    24184.0
#   242    24301.0
#   243    24417.0
#   244    24534.0
#   245    24651.0
#   dtype: float64),
#  (239    73863.0
#   240    73959.0
#   241    74053.0
#   242    74147.0
#   243    74239.0
#   244    74331.0
#   245    74422.0
#   dtype: float64,
#   239   -3180.0
#   240   -3642.0
#   241   -4068.0
#   242   -4603.0
#   243   -5104.0
#   244   -5726.0
#   245   -6313.0
#   dtype: float64),
#  (239    56092.0
#   240    56097.0
#   241    56101.0
#   242    56106.0
#   243    56110.0
#   244    56115.0
#   245    56119.0
#   dtype: float64,
#   239    4470.0
#   240    4470.0
#   241    4470.0
#   242    4470.0
#   243    4470.0
#   244    4470.0
#   245    4470.0
#   dtype: float64),
#  (239    22294.0
#   240    22326.0
#   241    22357.0
#   242    22389.0
#   243    22420.0
#   244    22451.0
#   245    22482.0
#   dtype: float64,
#   239    606.0
#   240    606.0
#   241    606.0
#   242    606.0
#   243    606.0
#   244    606.0
#   245    606.0
#   dtype: float64),
#  (239    800431.0
#   240    801786.0
#   241    803134.0
#   242    804475.0
#   243    805809.0
#   244    807136.0
#   245    808456.0
#   dtype: float64,
#   239    21278.0
#   240    21381.0
#   241    21484.0
#   242    21587.0
#   243    21690.0
#   244    21793.0
#   245    21896.0
#   dtype: float64),
#  (239   -1972630.0
#   240   -2041756.0
#   241   -2112191.0
#   242   -2183937.0
#   243   -2256992.0
#   244   -2331357.0
#   245   -2407028.0
#   dtype: float64,
#   239    13271.0
#   240    13340.0
#   241    13506.0
#   242    13592.0
#   243    13614.0
#   244    13746.0
#   245    13897.0
#   dtype: float64),
#  (239    59669.0
#   240    60671.0
#   241    61687.0
#   242    62719.0
#   243    63766.0
#   244    64829.0
#   245    65908.0
#   dtype: float64,
#   239    28383.0
#   240    30260.0
#   241    32262.0
#   242    34397.0
#   243    36673.0
#   244    39099.0
#   245    41687.0
#   dtype: float64),
#  (239    54947.0
#   240    55158.0
#   241    55368.0
#   242    55578.0
#   243    55788.0
#   244    55997.0
#   245    56205.0
#   dtype: float64,
#   239    526.0
#   240    527.0
#   241    527.0
#   242    527.0
#   243    528.0
#   244    528.0
#   245    528.0
#   dtype: float64),
#  (239    381495.0
#   240    382640.0
#   241    383780.0
#   242    384913.0
#   243    386041.0
#   244    387164.0
#   245    388281.0
#   dtype: float64,
#   239    9259.0
#   240    9264.0
#   241    9270.0
#   242    9275.0
#   243    9280.0
#   244    9286.0
#   245    9291.0
#   dtype: float64),
#  (239    217166.0
#   240    218758.0
#   241    220357.0
#   242    221964.0
#   243    223580.0
#   244    225203.0
#   245    226835.0
#   dtype: float64,
#   239    3296.0
#   240    3296.0
#   241    3296.0
#   242    3296.0
#   243    3296.0
#   244    3295.0
#   245    3295.0
#   dtype: float64),
#  (239    413103.0
#   240    419969.0
#   241    426941.0
#   242    434018.0
#   243    441204.0
#   244    448499.0
#   245    455905.0
#   dtype: float64,
#   239    1998.0
#   240    2006.0
#   241    2013.0
#   242    2021.0
#   243    2029.0
#   244    2036.0
#   245    2044.0
#   dtype: float64),
#  (239    130272.0
#   240    131603.0
#   241    132947.0
#   242    134301.0
#   243    135668.0
#   244    137047.0
#   245    138437.0
#   dtype: float64,
#   239    619.0
#   240    620.0
#   241    621.0
#   242    622.0
#   243    623.0
#   244    624.0
#   245    625.0
#   dtype: float64),
#  (239    142802.0
#   240    144162.0
#   241    145533.0
#   242    146914.0
#   243    148305.0
#   244    149706.0
#   245    151119.0
#   dtype: float64,
#   239    1563.0
#   240    1569.0
#   241    1575.0
#   242    1581.0
#   243    1587.0
#   244    1593.0
#   245    1599.0
#   dtype: float64),
#  (239    197706.0
#   240    198095.0
#   241    198482.0
#   242    198867.0
#   243    199250.0
#   244    199631.0
#   245    200010.0
#   dtype: float64,
#   239    6558.0
#   240    6571.0
#   241    6585.0
#   242    6598.0
#   243    6611.0
#   244    6624.0
#   245    6638.0
#   dtype: float64),
#  (239    6416.0
#   240    6433.0
#   241    6449.0
#   242    6465.0
#   243    6482.0
#   244    6498.0
#   245    6514.0
#   dtype: float64,
#   239    137.0
#   240    137.0
#   241    137.0
#   242    137.0
#   243    137.0
#   244    137.0
#   245    137.0
#   dtype: float64),
#  (239    149786.0
#   240    150133.0
#   241    150479.0
#   242    150823.0
#   243    151166.0
#   244    151508.0
#   245    151848.0
#   dtype: float64,
#   239    4233.0
#   240    4235.0
#   241    4238.0
#   242    4241.0
#   243    4243.0
#   244    4246.0
#   245    4249.0
#   dtype: float64),
#  (239    138850.0
#   240    138878.0
#   241    138905.0
#   242    138932.0
#   243    138958.0
#   244    138983.0
#   245    139008.0
#   dtype: float64,
#   239    9625.0
#   240    9627.0
#   241    9629.0
#   242    9631.0
#   243    9634.0
#   244    9636.0
#   245    9638.0
#   dtype: float64),
#  (239    167662.0
#   240    168119.0
#   241    168573.0
#   242    169027.0
#   243    169478.0
#   244    169928.0
#   245    170375.0
#   dtype: float64,
#   239    6711.0
#   240    6711.0
#   241    6711.0
#   242    6711.0
#   243    6711.0
#   244    6711.0
#   245    6711.0
#   dtype: float64),
#  (239    177764.0
#   240    178969.0
#   241    180178.0
#   242    181390.0
#   243    182606.0
#   244    183826.0
#   245    185050.0
#   dtype: float64,
#   239    2319.0
#   240    2322.0
#   241    2326.0
#   242    2329.0
#   243    2332.0
#   244    2336.0
#   245    2339.0
#   dtype: float64),
#  (239    117139.0
#   240    117372.0
#   241    117603.0
#   242    117832.0
#   243    118060.0
#   244    118286.0
#   245    118510.0
#   dtype: float64,
#   239    6704.0
#   240    6767.0
#   241    6830.0
#   242    6893.0
#   243    6958.0
#   244    7022.0
#   245    7087.0
#   dtype: float64),
#  (239   -4.771035e+14
#   240   -6.222154e+14
#   241   -8.114634e+14
#   242   -1.058271e+15
#   243   -1.380147e+15
#   244   -1.799921e+15
#   245   -2.347370e+15
#   dtype: float64,
#   239    2284.0
#   240    2290.0
#   241    2296.0
#   242    2302.0
#   243    2308.0
#   244    2314.0
#   245    2320.0
#   dtype: float64),
#  (239    27472.0
#   240    27768.0
#   241    28066.0
#   242    28367.0
#   243    28670.0
#   244    28976.0
#   245    29284.0
#   dtype: float64,
#   239    292.0
#   240    294.0
#   241    297.0
#   242    299.0
#   243    301.0
#   244    304.0
#   245    307.0
#   dtype: float64),
#  (239    58604.0
#   240    58767.0
#   241    58927.0
#   242    59087.0
#   243    59245.0
#   244    59402.0
#   245    59557.0
#   dtype: float64,
#   239    550.0
#   240    551.0
#   241    552.0
#   242    554.0
#   243    555.0
#   244    556.0
#   245    557.0
#   dtype: float64),
#  (239    108493.0
#   240    108847.0
#   241    109200.0
#   242    109553.0
#   243    109904.0
#   244    110255.0
#   245    110605.0
#   dtype: float64,
#   239    3082.0
#   240    3104.0
#   241    3126.0
#   242    3148.0
#   243    3170.0
#   244    3192.0
#   245    3214.0
#   dtype: float64),
#  (239    8629.0
#   240    8638.0
#   241    8647.0
#   242    8656.0
#   243    8665.0
#   244    8673.0
#   245    8682.0
#   dtype: float64,
#   239    468.0
#   240    468.0
#   241    468.0
#   242    468.0
#   243    469.0
#   244    469.0
#   245    469.0
#   dtype: float64),
#  (239    201909.0
#   240    201925.0
#   241    201941.0
#   242    201957.0
#   243    201972.0
#   244    201987.0
#   245    202001.0
#   dtype: float64,
#   239    16647.0
#   240    16649.0
#   241    16651.0
#   242    16653.0
#   243    16655.0
#   244    16656.0
#   245    16658.0
#   dtype: float64),
#  (239    34985.0
#   240    35070.0
#   241    35155.0
#   242    35240.0
#   243    35325.0
#   244    35410.0
#   245    35494.0
#   dtype: float64,
#   239    1106.0
#   240    1108.0
#   241    1111.0
#   242    1113.0
#   243    1116.0
#   244    1118.0
#   245    1121.0
#   dtype: float64),
#  (239    448691.0
#   240    448706.0
#   241    448720.0
#   242    448733.0
#   243    448746.0
#   244    448759.0
#   245    448771.0
#   dtype: float64,
#   239    33030.0
#   240    33030.0
#   241    33030.0
#   242    33030.0
#   243    33030.0
#   244    33030.0
#   245    33030.0
#   dtype: float64),
#  (239    324624.0
#   240    326347.0
#   241    328073.0
#   242    329801.0
#   243    331532.0
#   244    333266.0
#   245    335002.0
#   dtype: float64,
#   239    5092.0
#   240    5117.0
#   241    5143.0
#   242    5169.0
#   243    5195.0
#   244    5221.0
#   245    5247.0
#   dtype: float64),
#  (239    79142.0
#   240    80672.0
#   241    82231.0
#   242    83820.0
#   243    85439.0
#   244    87090.0
#   245    88772.0
#   dtype: float64,
#   239    231.0
#   240    232.0
#   241    233.0
#   242    234.0
#   243    234.0
#   244    235.0
#   245    236.0
#   dtype: float64),
#  (239    228501.0
#   240    229623.0
#   241    230746.0
#   242    231869.0
#   243    232994.0
#   244    234120.0
#   245    235246.0
#   dtype: float64,
#   239    5816.0
#   240    5828.0
#   241    5840.0
#   242    5853.0
#   243    5864.0
#   244    5876.0
#   245    5888.0
#   dtype: float64),
#  (239    155452.0
#   240    156726.0
#   241    158006.0
#   242    159293.0
#   243    160586.0
#   244    161887.0
#   245    163195.0
#   dtype: float64,
#   239    1540.0
#   240    1547.0
#   241    1554.0
#   242    1560.0
#   243    1567.0
#   244    1574.0
#   245    1581.0
#   dtype: float64),
#  (239    51286.0
#   240    51559.0
#   241    51832.0
#   242    52105.0
#   243    52379.0
#   244    52653.0
#   245    52928.0
#   dtype: float64,
#   239     993.0
#   240     999.0
#   241    1005.0
#   242    1011.0
#   243    1017.0
#   244    1022.0
#   245    1028.0
#   dtype: float64),
#  (239    181146.0
#   240    181421.0
#   241    181694.0
#   242    181964.0
#   243    182233.0
#   244    182498.0
#   245    182762.0
#   dtype: float64,
#   239    8277.0
#   240    8280.0
#   241    8282.0
#   242    8285.0
#   243    8287.0
#   244    8289.0
#   245    8291.0
#   dtype: float64),
#  (239    25551.0
#   240    25562.0
#   241    25572.0
#   242    25583.0
#   243    25593.0
#   244    25602.0
#   245    25612.0
#   dtype: float64,
#   239    1172.0
#   240    1173.0
#   241    1174.0
#   242    1174.0
#   243    1175.0
#   244    1176.0
#   245    1177.0
#   dtype: float64),
#  (239    199123.0
#   240    199902.0
#   241    200680.0
#   242    201457.0
#   243    202233.0
#   244    203009.0
#   245    203784.0
#   dtype: float64,
#   239    3144.0
#   240    3145.0
#   241    3145.0
#   242    3145.0
#   243    3146.0
#   244    3146.0
#   245    3146.0
#   dtype: float64),
#  (239    74577.0
#   240    75753.0
#   241    76947.0
#   242    78157.0
#   243    79386.0
#   244    80632.0
#   245    81897.0
#   dtype: float64,
#   239    290.0
#   240    292.0
#   241    293.0
#   242    294.0
#   243    296.0
#   244    297.0
#   245    298.0
#   dtype: float64),
#  (239    306841.0
#   240    308471.0
#   241    310103.0
#   242    311737.0
#   243    313372.0
#   244    315008.0
#   245    316647.0
#   dtype: float64,
#   239    7752.0
#   240    7868.0
#   241    7986.0
#   242    8106.0
#   243    8227.0
#   244    8351.0
#   245    8476.0
#   dtype: float64),
#  (239    914179.0
#   240    916387.0
#   241    918584.0
#   242    920770.0
#   243    922946.0
#   244    925110.0
#   245    927263.0
#   dtype: float64,
#   239    21139.0
#   240    21185.0
#   241    21231.0
#   242    21276.0
#   243    21321.0
#   244    21365.0
#   245    21409.0
#   dtype: float64),
#  (239    90958.0
#   240    91374.0
#   241    91790.0
#   242    92206.0
#   243    92623.0
#   244    93040.0
#   245    93457.0
#   dtype: float64,
#   239    410.0
#   240    410.0
#   241    410.0
#   242    410.0
#   243    410.0
#   244    410.0
#   245    410.0
#   dtype: float64),
#  (239    2367.0
#   240    2375.0
#   241    2383.0
#   242    2391.0
#   243    2399.0
#   244    2408.0
#   245    2416.0
#   dtype: float64,
#   239    58.0
#   240    58.0
#   241    58.0
#   242    58.0
#   243    58.0
#   244    58.0
#   245    58.0
#   dtype: float64),
#  (239    222414.0
#   240    223511.0
#   241    224608.0
#   242    225707.0
#   243    226807.0
#   244    227908.0
#   245    229010.0
#   dtype: float64,
#   239    3188.0
#   240    3192.0
#   241    3196.0
#   242    3200.0
#   243    3204.0
#   244    3208.0
#   245    3211.0
#   dtype: float64),
#  (239    121404.0
#   240    121879.0
#   241    122354.0
#   242    122829.0
#   243    123304.0
#   244    123779.0
#   245    124254.0
#   dtype: float64,
#   239    2207.0
#   240    2208.0
#   241    2209.0
#   242    2210.0
#   243    2211.0
#   244    2212.0
#   245    2213.0
#   dtype: float64),
#  (239    18980.0
#   240    19031.0
#   241    19082.0
#   242    19132.0
#   243    19182.0
#   244    19231.0
#   245    19280.0
#   dtype: float64,
#   239    718.0
#   240    725.0
#   241    731.0
#   242    738.0
#   243    744.0
#   244    751.0
#   245    758.0
#   dtype: float64),
#  (239    145411.0
#   240    146213.0
#   241    147018.0
#   242    147824.0
#   243    148633.0
#   244    149443.0
#   245    150255.0
#   dtype: float64,
#   239    1500.0
#   240    1503.0
#   241    1505.0
#   242    1508.0
#   243    1511.0
#   244    1514.0
#   245    1516.0
#   dtype: float64),
#  (239    7441.0
#   240    7480.0
#   241    7519.0
#   242    7558.0
#   243    7597.0
#   244    7636.0
#   245    7675.0
#   dtype: float64,
#   239    53.0
#   240    53.0
#   241    53.0
#   242    53.0
#   243    53.0
#   244    54.0
#   245    54.0
#   dtype: float64)]

# %%
test_submission = test_data.sort_values(["Province_State", "Date"])
confirmed = []
deaths = []
for i in range(50):
    confirmed.append(predictions[i][0].astype(int).tolist())
    deaths.append(predictions[i][1].astype(int).tolist())

confirmed = list(itertools.chain.from_iterable(confirmed))
deaths = list(itertools.chain.from_iterable(deaths))

test_submission.loc[:, "Confirmed"] = confirmed
test_submission.loc[:, "Deaths"] = deaths

test_submission = test_submission.sort_index().filter(items=['ForecastID', 'Confirmed', 'Deaths'])
test_submission.to_csv("Team15_arima_round2.csv", index=False)
